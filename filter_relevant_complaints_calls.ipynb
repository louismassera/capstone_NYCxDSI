# %%
import pandas as pd

# %%
calls = pd.read_csv('calls_since_june.csv')
# Out:
# C:\Anaconda\lib\site-packages\IPython\core\interactiveshell.py:2785: DtypeWarning: Columns (9,32,33) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
calls.head()
# Out:
#    Unnamed: 0  Unique Key            Created Date             Closed Date  \
# 0          92    40298199  09/16/2018 01:26:27 PM  09/17/2018 06:53:31 AM
# 1         111    40298201  09/16/2018 11:25:38 PM  09/17/2018 01:10:34 PM
# 2         125    40298202  09/17/2018 12:51:48 AM  09/17/2018 02:56:23 AM
# 3         126    40298203  09/16/2018 09:58:44 PM  09/17/2018 07:14:11 AM
# 4         177    40079222  08/22/2018 02:15:00 PM  08/24/2018 12:00:00 AM
#
#   Agency                         Agency Name  \
# 0    DPR  Department of Parks and Recreation
# 1   NYPD     New York City Police Department
# 2   NYPD     New York City Police Department
# 3   NYPD     New York City Police Department
# 4   DSNY            Department of Sanitation
#
#                         Complaint Type                           Descriptor  \
# 0              Overgrown Tree/Branches            Hitting Power/Phone Lines
# 1                     Blocked Driveway                       Partial Access
# 2                  Noise - Residential                         Loud Talking
# 3                      Noise - Vehicle                      Car/Truck Music
# 4  Request Large Bulky Item Collection  Request Large Bulky Item Collection
#
#                 Location Type Incident Zip  \
# 0                      Street        11374
# 1             Street/Sidewalk        11385
# 2  Residential Building/House        11235
# 3             Street/Sidewalk        10035
# 4                    Sidewalk        11221
#
#                     ...                    Vehicle Type Taxi Company Borough  \
# 0                   ...                             NaN                  NaN
# 1                   ...                             NaN                  NaN
# 2                   ...                             NaN                  NaN
# 3                   ...                             NaN                  NaN
# 4                   ...                             NaN                  NaN
#
#   Taxi Pick Up Location Bridge Highway Name Bridge Highway Direction  \
# 0                   NaN                 NaN                      NaN
# 1                   NaN                 NaN                      NaN
# 2                   NaN                 NaN                      NaN
# 3                   NaN                 NaN                      NaN
# 4                   NaN                 NaN                      NaN
#
#   Road Ramp Bridge Highway Segment   Latitude  Longitude  \
# 0       NaN                    NaN  40.718073 -73.859451
# 1       NaN                    NaN  40.695469 -73.892016
# 2       NaN                    NaN  40.590781 -73.948487
# 3       NaN                    NaN  40.803518 -73.939444
# 4       NaN                    NaN  40.694336 -73.932028
#
#                                   Location
# 0   (40.7180726706592, -73.85945086197565)
# 1  (40.695468990382686, -73.8920157126676)
# 2   (40.59078084550234, -73.9484868795183)
# 3  (40.80351779083321, -73.93944379835737)
# 4   (40.69433579492479, -73.9320277542523)
#
# [5 rows x 42 columns]

# %%
calls.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 962597 entries, 0 to 962596
# Data columns (total 42 columns):
# Unnamed: 0                        962597 non-null int64
# Unique Key                        962597 non-null int64
# Created Date                      962597 non-null datetime64[ns]
# Closed Date                       866587 non-null object
# Agency                            962597 non-null object
# Agency Name                       962597 non-null object
# Complaint Type                    962597 non-null object
# Descriptor                        946862 non-null object
# Location Type                     772822 non-null object
# Incident Zip                      929759 non-null object
# Incident Address                  802002 non-null object
# Street Name                       801960 non-null object
# Cross Street 1                    593169 non-null object
# Cross Street 2                    590399 non-null object
# Intersection Street 1             127079 non-null object
# Intersection Street 2             126249 non-null object
# Address Type                      938202 non-null object
# City                              929973 non-null object
# Landmark                          498 non-null object
# Facility Type                     341905 non-null object
# Status                            962597 non-null object
# Due Date                          481166 non-null object
# Resolution Description            873184 non-null object
# Resolution Action Updated Date    915196 non-null object
# Community Board                   962597 non-null object
# BBL                               759570 non-null float64
# Borough                           962597 non-null object
# X Coordinate (State Plane)        901699 non-null float64
# Y Coordinate (State Plane)        901699 non-null float64
# Open Data Channel Type            962597 non-null object
# Park Facility Name                962597 non-null object
# Park Borough                      962597 non-null object
# Vehicle Type                      23 non-null object
# Taxi Company Borough              745 non-null object
# Taxi Pick Up Location             3959 non-null object
# Bridge Highway Name               1265 non-null object
# Bridge Highway Direction          1263 non-null object
# Road Ramp                         1249 non-null object
# Bridge Highway Segment            1954 non-null object
# Latitude                          901699 non-null float64
# Longitude                         901699 non-null float64
# Location                          901699 non-null object
# dtypes: datetime64[ns](1), float64(5), int64(2), object(34)
# memory usage: 308.4+ MB

# %%
complaints_to_look_for = ["Illegal Parking", "Blocked Driveway", "Street Sign - Damaged", "Street Sign - Missing", "Street Condition", "Street Sign - Dangling", "Sewer", "Street Light Condition", "Traffic Signal Condition", "Broken Parking Meter", "Root/Sewer/Sidewalk Condition", "Highway Condition"]

# %%
relevant_calls = calls.loc[calls['Complaint Type'].isin(complaints_to_look_for)]

# %%
relevant_calls.shape
# Out:
# (210335, 42)

# %%
relevant_calls.to_csv('relevant_calls_since_june.csv')
