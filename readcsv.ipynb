# %%
import pandas as pd
irr = pd.read_csv('data/irr.csv')
al = pd.read_csv('data/al.csv')
jm = pd.read_csv('data/jm.csv')
# Out:
# C:\Users\jcorrea\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel\parentpoller.py:116: UserWarning: Parent poll failed.  If the frontend dies,
#                 the kernel may be left running.  Please let us know
#                 about your system (bitness, Python, etc.) at
#                 ipython-dev@scipy.org
#   ipython-dev@scipy.org""")

# %%
al
# Out:
#        Unnamed: 0                                  uuid           city state  \
# 0               0  17ca1b76-3034-37ba-950c-b3aa0853d111  Staten Island    NY
# 1               1  6b6006aa-4d6c-3c61-bbf1-48e989d4b53b  Staten Island    NY
# 2               2  770cd844-cb83-3414-8444-3bb319d19e4b  Staten Island    NY
# 3               3  ca3381b7-0941-3146-9462-f68debddf4c6      Elizabeth    NJ
# 4               4  e8f2eb2a-cfb1-314e-9b06-6bf215b77139      Elizabeth    NJ
# 5               5  1ece3af1-d4c0-3399-a0b6-c05e1adb55a4      Elizabeth    NJ
# 6               6  3f89ff35-196a-3ac5-ba2d-1ae19a2b7af9      Elizabeth    NJ
# 7               7  2d32afd9-0436-3169-9c3c-8d55da7e41c5      Elizabeth    NJ
# 8               8  32d535c5-4015-3ec2-b8e9-3770525c2540      Elizabeth    NJ
# 9               9  37069b8a-975a-3dd9-adf2-38b5165344fd      Elizabeth    NJ
# 10             10  eb76c1c9-0c83-3e94-ae16-25fdd30b9bd5      Elizabeth    NJ
# ...

# %%
irr
# Out:
#       Unnamed: 0        id                                             alerts  \
# 0              0  62466158  [{'country': 'US', 'nThumbsUp': 1, 'city': 'Ma...
# 1              1  63205871  [{'country': 'US', 'nThumbsUp': 0, 'city': 'Br...
# 2              2  62726115  [{'country': 'US', 'nThumbsUp': 6, 'city': 'Je...
# 3              3  62886114                                                 []
# 4              4  62606116  [{'country': 'US', 'nThumbsUp': 0, 'city': 'Ma...
# 5              5  62465958  [{'country': 'US', 'nThumbsUp': 1, 'city': 'Br...
# 6              6  62885814  [{'country': 'US', 'nThumbsUp': 0, 'city': 'Br...
# 7              0  63661386  [{'country': 'US', 'nThumbsUp': 0, 'city': 'Qu...
# 8              1  64141962                                                 []
# 9              2  64141782                                                 []
# 10             3  63580827                                                 []
# ...

# %%
jm
# Out:
#        Unnamed: 0        uuid                   blocking_alert_uuid  \
# 0               0  1091249488                                   NaN
# 1               1  1095145876                                   NaN
# 2               2  1050403853  32d535c5-4015-3ec2-b8e9-3770525c2540
# 3               3  1014506920  e8f2eb2a-cfb1-314e-9b06-6bf215b77139
# 4               4   936779831  ca3381b7-0941-3146-9462-f68debddf4c6
# 5               5  1070660215  1ece3af1-d4c0-3399-a0b6-c05e1adb55a4
# 6               6  1061763046  37069b8a-975a-3dd9-adf2-38b5165344fd
# 7               7  1054503000  2d32afd9-0436-3169-9c3c-8d55da7e41c5
# 8               8  1053843031  3f89ff35-196a-3ac5-ba2d-1ae19a2b7af9
# 9               9  1089266549                                   NaN
# 10             10  1089093139                                   NaN
# 11             11  1095083256                                   NaN
# 12             12  1091297778                                   NaN
# ...
